# %% [markdown]
# # 调用千帆大模型
#
# ## 0. 报名"游戏大模王"比赛
#
# Datawhale专属报名链接：[https://cloud.baidu.com/survey_summit/qrl.html?track=C452658](https://cloud.baidu.com/survey_summit/qrl.html?track=C452658)
#
# 如是第一次使用千帆大模型，则报名后会赠送100元代金券，可用于调用千帆大模型。
# 此外，千帆大模型平台自带20元代金券。
#
# ## 1. 创建应用
# ### 首先，在这个页面登录百度智能云。
#
# [https://cloud.baidu.com/product/wenxinworkshop](https://cloud.baidu.com/product/wenxinworkshop)
#
# ### 进去后点击左侧的“应用接入”，再点击“创建应用”
#
# ![image.png](attachment:image.png)
#
# ### 进去后填写“应用名称”和“应用描述”，并按最下方的“确定”创建应用。
#
# ![image-2.png](attachment:image-2.png)
#
# ### 随后就会看到自己新建的应用，复制“API Key”和“Secret Key”（这个要点击下方的显示按钮才显示），这个是你调用千帆大模型的凭证。
#
# ![image-3.png](attachment:image-3.png)
#
# ## 2. 开通付费
# ### 创建应用后，需要开通付费，才能调用千帆大模型。点击左侧的“计费管理”，找到你需要调用的模型，点击“开通付费”。即可开通。建议开通前3个模型。
#
# ![image-4.png](attachment:image-4.png)
# ……

# %% [markdown]
# # 安装千帆大模型SDK

# %%
# !pip install qianfan
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
import qianfan

# %%
comp = qianfan.Completion(ak="wMA8Ifco3x3H6FrVc5oVkHOR", sk="DySPfzYSBQRxNz2YbjR5aDf65UKXRmys")

# %% [markdown]
# # 查看支持的模型
# ## ERNIE-Bot 对应的是文心一言，ERNIE-Bot-4对应的是文心一言4.0，而turbo版本就是推理加速版（建议用这个）。而其他模型就是别人开源的大模型。

# %%
comp._supported_models().keys()
# Out:
# dict_keys(['ERNIE-Bot-turbo', 'ERNIE-Bot', 'ERNIE-Bot-4', 'ERNIE-Bot-8k', 'BLOOMZ-7B', 'Llama-2-7b-chat', 'Llama-2-13b-chat', 'Llama-2-70b-chat', 'Qianfan-BLOOMZ-7B-compressed', 'Qianfan-Chinese-Llama-2-7B', 'ChatGLM2-6B-32K', 'AquilaChat-7B', 'UNSPECIFIED_MODEL'])

# %% [markdown]
# # QA
# ## ak/sk泄露了怎么办？
# ### 直接删除对应的应用即可，这样泄露的ak/sk就失效了。
